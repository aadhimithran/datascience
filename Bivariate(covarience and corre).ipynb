# %%
import pandas as pd

# %%
dataset = pd. read_csv("preplacementdata.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.drop(["sl_no"],inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.cov(numeric_only=True)
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      60.348373      42.897137      37.659225
# hsc_p         60.348373     118.755706      34.819820      35.461678
# degree_p      42.897137      34.819820      54.151103      21.929469
# etest_p       37.659225      35.461678      21.929469     176.251018
# mba_p         24.535952      22.555846      17.272020      16.886973
# salary    901754.893936  763359.777657  465131.504238  384234.419257
#
#                   mba_p        salary
# ssc_p         24.535952  9.017549e+05
# hsc_p         22.555846  7.633598e+05
# degree_p      17.272020  4.651315e+05
# etest_p       16.886973  3.842344e+05
# mba_p         34.028376  1.262455e+05
# salary    126245.485547  2.395714e+10

# %%
 correlation_matrix=dataset.corr(numeric_only=True)

# %%
 correlation_matrix
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# #AASINGNMENT

# %% [markdown]
# # 1) co-varience difference between ENTERANCE TEST BETWEEN DEGREE
# # 2) co-varience difference between ENTERANCE TEST BETWEEN MBA PASS MARK

# %% [markdown]
# 1) co-varience between ENTERANCE TEST BETWEEN DEGREE = 0.22
# 2)co-varience between ENTERANCE TEST BETWEEN MBA PASS MARK=0.21

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figure=(10,5))
plt.scatter(dataset["etest_p"],dataset["degree_p"])
plt.title(" co-variencef ENTERANCE TEST BETWEEN DEGREE")
plt.xlabel("degree")
plt.ylabel("enternce test")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figure=(10,5))
plt.scatter(dataset["etest_p"],dataset["mba_p"])
plt.title(" co-variencef ENTERANCE TEST BETWEEN MBA PASS MARK")
plt.xlabel("mba_p")
plt.ylabel("enternce test")
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 4)) # fig sixe length breadth of boxes
sns.heatmap( correlation_matrix, annot=True, cmap='RdBu',fmt=".2f" ,linewidths=0.5)# annot denotes the value inside the box
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [raw]
# #correletion relationship betwen MBA_P AND SALARY=0.14  This is positive correletion and 14% directltly protional(increase only 14%)
